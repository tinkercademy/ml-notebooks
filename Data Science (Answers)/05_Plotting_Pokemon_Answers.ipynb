# %% [markdown]
# <a href="https://colab.research.google.com/github/tinkercademy/ml-notebooks/blob/main/Data Science (Answers)/05_Plotting_Pokemon_Answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting in Python

# %%
# If you are mounting from google drive, uncomment and run the below lines. Else, you can ignore this
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#If you are importing from Colab's Files, uncomment and use the below lines. Else, you can ignore this
# data = pd.read_csv("pokemon.basestats.csv", index_col = 'Name')

# %% [markdown]
# ## Matplotlib
#
# In this notebook, we'll start plotting things out using the `matplotlib` library.
#
# Most notebooks will add lines like the below at the start, to indicate early on what modules have been imported. You want to do this early on for neatness and for others to know what modules they need to run your code, so even if you realise later on that you want to add modules, you should still come all the way to the top and import them.
#
# `%matplotlib inline` is a special command that configures the plotting library, matplotlib, to show its results inline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokemon.basestats.csv", index_col = 'Name')
data = data.loc[:,'HP':'Speed'].head(13) #slice out a subset of the dataset that only contains numerical information. Here we'll only keep the first 13 rows for testing purposes.
data
# Out:
#                   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Name
# Bulbasaur         45      49       49       65       65     45
# Ivysaur           60      62       63       80       80     60
# Venusaur          80      82       83      100      100     80
# Mega Venusaur     80     100      123      122      120     80
# Charmander        39      52       43       60       50     65
# Charmeleon        58      64       58       80       65     80
# Charizard         78      84       78      109       85    100
# Mega Charizard X  78     130      111      130       85    100
# Mega Charizard Y  78     104       78      159      115    100
# Squirtle          44      48       65       50       64     43
# Wartortle         59      63       80       65       80     58
# Blastoise         79      83      100       85      105     78
# Mega Blastoise    79     103      120      135      115     78

# %% [markdown]
# <hr>

# %% [markdown]
# To plot, we just use the handy `.plot()` function, built into each DataFrame:

# %%
data.plot()
# Out:
# <Axes: xlabel='Name'>

# %% [markdown]
# However, the graph looks like someone trampled all over some leaves. Our secondary school maths teachers would not be pleased. Let's fix things up a bit by making adjustments to the `plt` module. See if you can figure out what each line means.
#
# Note the ordering--you plot _first_, in the first line, then you adjust the settings!

# %%
data.loc["Bulbasaur", :].plot()
# Out:
# <Axes: >

# %%
data.loc["Bulbasaur"].plot()
plt.ylabel('Stat Points')
plt.xlabel('Stat')
# Out:
# Text(0.5, 0, 'Stat')

# %% [markdown]
# Now, how about showing more than one pokemon at a time? You can just plot each of them separately.

# %%
data.loc["Venusaur"].plot()
data.loc["Charizard"].plot()
plt.ylabel('Stat Points')
plt.xlabel('Stat')
plt.legend()

# %% [markdown]
# ### <font color="red">Exercise 1: Plotting Pokemon</font>
#
# Plot the stats of Venusaur, Charizard, and Blastoise.
#
# Extra challenge: But their plot line colours don't match their types! See if you can fix this. Look through the `.plot` [documentation](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html) to make Venusaur's plot line green, Charizard's plot line orange, and Blastoise's plot line blue.

# %%
data.loc["Venusaur"].plot(color="green") #google for solution and show off stackoverflow.com solutions
data.loc["Charizard"].plot(color="orange") #google for matplotlib colours to see all the options
data.loc["Blastoise"].plot(color="#5991ff") #Google "colourpicker" for the hex colour codes - here we use a hex colour code for blue
plt.ylabel('Stat Points')
plt.xlabel('Stat')
plt.legend()

# %% [markdown]
# ### <font color="red">Exercise 2: Minimum & Maximum Stats</font>
#
# Plot the minimum stats for all the Pokemon in the dataset. Add a second plot line that shows the maximum stats. Hint: remember the .min() and .max() operations we could call on dataframes?

# %%
data = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokemon.basestats.csv", index_col = 'Name')
data = data.loc[:,'HP':'Speed']
data.head()
# Out:
#                HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Name
# Bulbasaur      45      49       49       65       65     45
# Ivysaur        60      62       63       80       80     60
# Venusaur       80      82       83      100      100     80
# Mega Venusaur  80     100      123      122      120     80
# Charmander     39      52       43       60       50     65

# %%
data.min().plot(label='min')
data.max().plot(label='max')
plt.legend(loc='best')

# %% [markdown]
# ### <font color="red">Exercise 3: Other plots</font>
#
# Try this out. What does this plot? What does the `s` parameter refer to? What is 5e4?

# %%
data = pd.read_csv('https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokedex_(Update_2021.04).csv', index_col="name")
data["totaldefense"] = data["hp"]*data["defense"]*data["sp_defense"]
data.plot(kind='scatter', x='attack', y='sp_attack', s=data['totaldefense']/5e4)
# Out:
# <Axes: xlabel='attack', ylabel='sp_attack'>

# %%
#this introduces python's scientific notation

#Steps you can take to find this on your own:
#  google 'python what is 5e4'
#  look for scientific notation mention
#  google python scientific notation
#  click on first result to get wiki

# here, 'e' returns a float multiplied by the specified power of 10.
# For example:
#      1e3 = 1000.0    (1 * 10**3)
#      1e6 = 1000000.0
#      1e9 = 1000000000.0

#This plot is therefore showing attack vs sp_attack on the x and y axes,
# while also showing totaldefense using the size of each datapoint.
# It's a neat way of showing 3 dimensions of data in 2D format.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Plot.ly

# %% [markdown]
# There are also other plotting options available. One popular one is plot.ly, a data visualization toolbox that’s compatible with  Jupyter notebooks. It has an offline mode that allows you to save files locally inside ipython notebooks. Plotly is nice because you can dynamically zoom in on plot sections and hover over your plot to identify specific data points.
#
# Note: saving your notebooks with plots results in a much larger file size than without. To save without plots, simply clear your output by going to Cell > All Output > Clear.

# %% [markdown]
# First, we must import required libraries:

# %%
#import modules
import pandas as pd
import plotly
import plotly.graph_objs as go

# %%
#let's first setup a dataframe to use, same as before, except this time we store it in a variable called df
df = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokemon.basestats.csv", index_col = 'Name')
df = df.loc[:, "HP":"Speed"]
df.head()
# Out:
#                HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Name
# Bulbasaur      45      49       49       65       65     45
# Ivysaur        60      62       63       80       80     60
# Venusaur       80      82       83      100      100     80
# Mega Venusaur  80     100      123      122      120     80
# Charmander     39      52       43       60       50     65

# %% [markdown]
# ### Plotting with Plotly
# Plotly has a few different ways to create plots. One of these is called Plotly Express, which is designed to be a way to quickly plot data with minimal code. The big downside to Plotly Express is that you really don't have many customisation options. We've already seen a basic plotting option with matplotlib, so we're going to skip Plotly Express and instead jump straight into the Plotly's full plotting options.

# %%
#Example 1

#specify the x and y coordinates
x_coords = df.columns
y_coords = df.loc["Bulbasaur", :]

#Set up the data variable
data = [go.Scatter(x=x_coords, y= y_coords)]

fig = go.Figure(data = data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7eca1899-6ccf-45f2-843b-9f210847f4dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eca1899-6ccf-45f2-843b-9f210847f4dc")) {                    Plotly.newPlot(                        "7eca1899-6ccf-45f2-843b-9f210847f4dc",                        [{"x":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"],"y":[45,49,49,65,65,45],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth" ...

# %%
#Example 2: How to customise

#specify the x and y coordinates
x_coords = df.columns
y_coords = df.loc["Bulbasaur", :]
y_coords2 = df.loc["Charmander", :]
y_coords3 = df.loc["Squirtle", :]

#Set up the data variable
firstplot = go.Scatter(x=x_coords, y= y_coords,
                      marker = dict(color = "green"),  # you can also use hex colour codes to specify a colour
                      mode = "markers+lines",
                      name = 'Bulbasaur')
secondplot = go.Scatter(x=x_coords, y= y_coords2,
                      marker = dict(color = "orange"),
                      mode = "markers",
                      text = ['This HP seems really low', '', '', '', '', "Wah so fast!"],
                      name = 'Charmander')
thirdplot = go.Scatter(x=x_coords, y= y_coords3,
                      marker = dict(color = "blue"),
                      mode = "lines",
                      name = 'Squirtle')
data = [firstplot, secondplot, thirdplot]

#setup layout
layout = go.Layout(title = 'Stats of Pokemon',
                  xaxis = {'title': 'Stats'},
                  yaxis = {'title': 'Value'})

fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bbdcbde3-87ae-4ad5-995f-e8609ac8a690" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbdcbde3-87ae-4ad5-995f-e8609ac8a690")) {                    Plotly.newPlot(                        "bbdcbde3-87ae-4ad5-995f-e8609ac8a690",                        [{"marker":{"color":"green"},"mode":"markers+lines","name":"Bulbasaur","x":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"],"y":[45,49,49,65,65,45],"type":"scatter"},{"marker":{"color":"orange"},"mode":"markers","name":"Charmander","text":["This HP seems really low","","","","","Wah so fast!"],"x":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"],"y":[39,52,43,60,50,65],"type":"scatter"},{"marker":{"color":"blue"},"mode":"lines","name":"Squirtle","x":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"],"y":[44,48,65,50,64,43],"type":"scatter"}],                        {"title":{"text":"Stats of Pokemon"},"xaxis":{"title":{"text":"Stats"}},"yaxis":{"title":{"text":"Value"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth" ...

# %% [markdown]
# So far we've only plotted scatter plots with plotly. What about a bar graph? You'll notice we use 'plotly.graph_objs.Scatter' in our above examples. To plot a bar graph, we'll use plotly.graph_objs.Bar. Using the same CSV file above, plot the number of each type of Pokemon with a bar graph.

# %%
#Example 3 - bar graphs

#setup the data variable
firstplot = go.Bar(name='Venusaur', x=df.columns, y=df.loc["Venusaur", :], marker_color="green")
secondplot = go.Bar(name='Charizard', x=df.columns, y=df.loc["Charizard", :], marker_color="orangered")
thirdplot = go.Bar(name='Blastoise', x=df.columns, y=df.loc["Blastoise", :], marker_color="blue")
data = [firstplot, secondplot, thirdplot]

#pass the coords into a scatterplot object and show the plot
fig = go.Figure(data = data)
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="67435f41-ff43-4855-945d-45757076b303" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67435f41-ff43-4855-945d-45757076b303")) {                    Plotly.newPlot(                        "67435f41-ff43-4855-945d-45757076b303",                        [{"marker":{"color":"green"},"name":"Venusaur","x":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"],"y":[80,82,83,100,100,80],"type":"bar"},{"marker":{"color":"orangered"},"name":"Charizard","x":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"],"y":[78,84,78,109,85,100],"type":"bar"},{"marker":{"color":"blue"},"name":"Blastoise","x":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"],"y":[79,83,100,85,105,78],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"typ ...

# %% [markdown]
# We can also plot histograms that track the number of occurrences in a dataset. Here we use the ```.count()``` and ```.groupby()``` methods to count the number of each Type of pokemon (e.g. Fire, Water, etc.)
#
# We also create a list of colours to customise our graph and make each Type display in an appropriate colour (e.g. orange for Fire, yellow for Electric, etc.)

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokemon.basestats.csv", index_col = 'Name')

# Defining colors for graphs
colors = {
    "Bug": "#A6B91A",
    "Dark": "#705746",
    "Dragon": "#6F35FC",
    "Electric": "#F7D02C",
    "Fairy": "#D685AD",
    "Fighting": "#C22E28",
    "Fire": "#EE8130",
    "Flying": "#A98FF3",
    "Ghost": "#735797",
    "Grass": "#7AC74C",
    "Ground": "#E2BF65",
    "Ice": "#96D9D6",
    "Normal": "#A8A77A",
    "Poison": "#A33EA1",
    "Psychic": "#F95587",
    "Rock": "#B6A136",
    "Steel": "#B7B7CE",
    "Water": "#6390F0",
}

types = (df2.groupby(['Type 1'])['#'].count())
types_name = list(types.keys())

x_coords = types_name
y_coords = types.values

data = [go.Bar(x=x_coords, y= y_coords, marker = dict(color = list(colors.values())))]

layout = go.Layout()

fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b84eede7-e0bb-40c5-84ce-bf06447855d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b84eede7-e0bb-40c5-84ce-bf06447855d6")) {                    Plotly.newPlot(                        "b84eede7-e0bb-40c5-84ce-bf06447855d6",                        [{"marker":{"color":["#A6B91A","#705746","#6F35FC","#F7D02C","#D685AD","#C22E28","#EE8130","#A98FF3","#735797","#7AC74C","#E2BF65","#96D9D6","#A8A77A","#A33EA1","#F95587","#B6A136","#B7B7CE","#6390F0"]},"x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"y":[69,31,32,44,17,27,52,4,32,70,32,24,98,28,57,44,27,112],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"s ...

# %% [markdown]
# Plotly also has a way to create attractive tables out of dataframes:

# %%
import plotly.figure_factory as ff

df3 = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
# You can also do this with our Pokemon dataset, but be warned your browser will be laggy/freeze as the code runs as it needs to process 1000+ rows

fig = go.Figure(data = ff.create_table(df3))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="46699062-61ce-4c0e-b22a-da7247b655c9" class="plotly-graph-div" style="height:710px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46699062-61ce-4c0e-b22a-da7247b655c9")) {                    Plotly.newPlot(                        "46699062-61ce-4c0e-b22a-da7247b655c9",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0,0],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5],[1,1,1,1],[0.5,0.5,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eSchool\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eWomen\u003c\u002fb\u003e","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eMen\u003c\u002fb\u003e","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eGap\u003c\u002fb\u003e","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MIT","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"94","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"152","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"58","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Stanford","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"96","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"151","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"55","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Harvard","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"112","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"165","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"53","x":2.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"U.Penn","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"92","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"141","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"49","x":2.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Princeton","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"90","x":0.55,"xanchor": ...

# %% [markdown]
# Plotly also interfaces with some pretty neat extensions:

# %% [markdown]
# ### <font color="red">Exercise 10: Mapbox
#
# One of these extensions is Mapbox, which allows us to plot longitude and latitude coordinates on a map. To plot on Mapbox maps with Plotly you'll need a Mapbox account and a Mapbox Access Token.

# %%
#Plotting multiple coordinates:

#Add your own mapbox API Token here
#mapbox_access_token = 'ADD_YOUR_TOKEN_HERE'
mapbox_access_token = 'pk.eyJ1IjoibWlrZXRpbmtlcnRhbmtlciIsImEiOiJjajZvajA2bWEwNXhxMzNud2NlMHUyaHI0In0.XFNKTNUWWVK-OO_r1kvXqQ'


data = [go.Scattermapbox(
        lat=['38.91427','38.91538','38.91458',
             '38.92239','38.93222','38.90842',
             '38.91931','38.93260','38.91368',
             '38.88516','38.921894','38.93206',
             '38.91275'],
        lon=['-77.02827','-77.02013','-77.03155',
             '-77.04227','-77.02854','-77.02419',
             '-77.02518','-77.03304','-77.04509',
             '-76.99656','-77.042438','-77.02821',
             '-77.01239'],
        mode='markers',
        marker=dict(size=9),
        text=["The coffee bar","Bistro Bohem","Black Cat",
             "Snap","Columbia Heights Coffee","Azi's Cafe",
             "Blind Dog Cafe","Le Caprice","Filter",
             "Peregrine","Tryst","The Coupe",
             "Big Bear Cafe"],
        )]
layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(lat=38.92, lon=-77.07),
        pitch=0,
        zoom=10
    ),
)

fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5553d0ba-e513-4846-826c-d4580e4580cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5553d0ba-e513-4846-826c-d4580e4580cd")) {                    Plotly.newPlot(                        "5553d0ba-e513-4846-826c-d4580e4580cd",                        [{"lat":["38.91427","38.91538","38.91458","38.92239","38.93222","38.90842","38.91931","38.93260","38.91368","38.88516","38.921894","38.93206","38.91275"],"lon":["-77.02827","-77.02013","-77.03155","-77.04227","-77.02854","-77.02419","-77.02518","-77.03304","-77.04509","-76.99656","-77.042438","-77.02821","-77.01239"],"marker":{"size":9},"mode":"markers","text":["The coffee bar","Bistro Bohem","Black Cat","Snap","Columbia Heights Coffee","Azi's Cafe","Blind Dog Cafe","Le Caprice","Filter","Peregrine","Tryst","The Coupe","Big Bear Cafe"],"type":"scattermapbox"}],                        {"autosize":true,"hovermode":"closest","mapbox":{"accesstoken":"pk.eyJ1IjoibWlrZXRpbmtlcnRhbmtlciIsImEiOiJjajZvajA2bWEwNXhxMzNud2NlMHUyaHI0In0.XFNKTNUWWVK-OO_r1kvXqQ","bearing":0,"center":{"lat":38.92,"lon":-77.07},"pitch":0,"zoom":10},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoor ...

# %% [markdown]
# ### Radar Charts

# %%
# Visualizing single Pokemon statistics
# source: https://www.kaggle.com/lakshyaag/data-visualization-pokemon-data

# Defining colors for graphs
colors = {"Bug": "#A6B91A","Dark": "#705746","Dragon": "#6F35FC","Electric": "#F7D02C","Fairy": "#D685AD","Fighting": "#C22E28","Fire": "#EE8130","Flying": "#A98FF3","Ghost": "#735797","Grass": "#7AC74C","Ground": "#E2BF65","Ice": "#96D9D6","Normal": "#A8A77A","Poison": "#A33EA1","Psychic": "#F95587","Rock": "#B6A136","Steel": "#B7B7CE","Water": "#6390F0",}

def polar_pokemon_stats(pkmn_name):
    poke = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokemon.basestats.csv")
    pkmn = poke[poke.Name == pkmn_name]
    obj = go.Scatterpolar(
        r=[
            pkmn['HP'].values[0],
            pkmn['Attack'].values[0],
            pkmn['Defense'].values[0],
            pkmn['Sp. Atk'].values[0],
            pkmn['Sp. Def'].values[0],
            pkmn['Speed'].values[0],
            pkmn['HP'].values[0]
        ],
        theta=[
            'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'HP'
        ],
        fill='toself',
        marker=dict(
            color=colors[pkmn['Type 1'].values[0]]
        ),
        name=pkmn['Name'].values[0]
    )

    return obj


def plot_single_pokemon(name):
    layout = go.Layout(
        polar=dict(
            radialaxis=dict(
                visible=True,
                range=[0, 250]
            )
        ),
        showlegend=False,
        title="Stats of {}".format(name)
    )

    pokemon_figure = go.Figure(data=[polar_pokemon_stats(name)], layout=layout)
    pokemon_figure.show()

name = 'Charizard'
plot_single_pokemon(name)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2e001580-c43b-4789-b1d2-09c5d650f253" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e001580-c43b-4789-b1d2-09c5d650f253")) {                    Plotly.newPlot(                        "2e001580-c43b-4789-b1d2-09c5d650f253",                        [{"fill":"toself","marker":{"color":"#EE8130"},"name":"Charizard","r":[78,84,78,109,85,100,78],"theta":["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed","HP"],"type":"scatterpolar"}],                        {"polar":{"radialaxis":{"range":[0,250],"visible":true}},"showlegend":false,"title":{"text":"Stats of Charizard"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinew ...

# %% [markdown]
# ### Histograms (Distribution Plots)

# %%
import plotly.figure_factory as ff
df4 = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/gdp_pop_all.csv", index_col = "country")
life_exp = ff.create_distplot([df4.lifeExp_1952, df4.lifeExp_2007], ['Life Expectancy 1952', 'Life Expectancy 2007'], bin_size=2)
life_exp.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="605fcb50-55dd-4e0b-94d0-f0a40df85f48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("605fcb50-55dd-4e0b-94d0-f0a40df85f48")) {                    Plotly.newPlot(                        "605fcb50-55dd-4e0b-94d0-f0a40df85f48",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Life Expectancy 1952","marker":{"color":"rgb(31, 119, 180)"},"name":"Life Expectancy 1952","opacity":0.7,"x":[43.077,30.015,38.223,47.622,31.975,39.031,38.523,35.463,38.092,40.715,39.143,42.111,40.477,34.812,41.893,34.482,35.928,34.078,37.003,30.0,43.149,33.609,32.5,42.27,42.138,38.48,42.723,36.681,36.256,33.685,40.543,50.986,42.873,31.286,41.725,37.444,36.324,52.724,40.0,46.471,37.278,30.331,32.978,45.009,38.635,41.407,41.215,38.596,44.6,39.978,42.038,48.451,62.485,40.414,50.917,68.75,54.745,50.643,57.206,59.421,45.928,48.357,45.262,42.023,37.579,41.912,58.53,50.789,42.314,55.191,62.649,43.902,64.28,59.1,68.44,66.071,55.088,28.801,50.939,37.484,39.417,44.0,60.96,37.373,37.468,44.869,45.32,65.39,63.03,43.158,50.056,47.453,55.565,55.928,48.463,42.244,36.319,36.157,37.578,43.436,47.752,39.875,60.396,57.593,45.883,58.5,50.848,40.412,43.16,32.548,55.23,66.8,68.0,53.82,59.6,61.21,66.87,70.78,66.55,67.41,67.5,65.86,64.03,72.49,66.91,65.94,59.164,72.13,72.67,61.31,59.82,61.05,57.996,64.36,65.57,64.94,71.86,69.62,43.585,69.18,69.12,69.39],"xaxis":"x","xbins":{"end":72.67,"size":2,"start":28.801},"yaxis":"y","type":"histogram"},{"autobinx":false,"histnorm":"probability density","legendgroup":"Life Expectancy 2007","marker":{"color":"rgb(255, 127, 14)"},"name":"Life Expectancy 2007","opacity":0.7,"x":[72.301,42.731,56.728,50.728,52.295,49.58,50.43,44.741,50.651,65.152,46.462,55.322,48.328,54.791,71.338,51.579,58.04,52.947,56.735,59.448,60.022,56.007,46.388,54.11,42.592,45.678,73.952,59.443,48.303,54.467,64.164,72.801,71.164,42.082,52.906,56.867,46.859,76.442,46.242,65.528,63.062,42.568,48.159,49.339,58.556,39.613,52.517,58.42,73.923,51.542,42.384,43.487,75.32,65.554,72.39,80.653,78.553,72.889,78.782,78.273,72.235,74.994,71.878,70.259,60.916,70.198,72.567,76.195,72.899,75.537,71.752,71.421,78.746,69.819,78.242,76.384,73.747,43.828,75.635,64.062,59.723,72.961,82.208,64.698,70.65,70.964,59.545,80.745,82.603,72.535,67.297,78.623,77.588,71.993,74.241,66.803,62.069,63.785,75.64,65.483,71.688,72.777,79.972,72.396,74.143,78.4,70.616,74.249,73.422,62.698,76.423,79.829,79.441,74.852,73.005,75.748,76.486,78.332,79.313,80.657,79.406,79.483,73.338,81.757,78.885,80.546,74.543,79.762,80.196,75.563,78.098,72.476,74.002,74.663,77.926,80.941,80.884,81.701,71.777,79.425,81.235,80.204],"xaxis":"x","xbins":{"end":82.603,"size":2,"start":39.613},"yaxis":"y","type":"histogram"},{"legendgroup":"Life Expectancy 1952","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"Life Expectancy 1952","showlegend":false,"x":[28.801,28.888738,28.976475999999998,29.064214,29.151951999999998,29.23969,29.327427999999998,29.415166,29.502903999999997,29.590642,29.678379999999997,29.766118,29.853855999999997,29.941594,30.029331999999997,30.11707,30.204808,30.292545999999998,30.380284,30.468021999999998,30.55576,30.643497999999997,30.731236,30.818973999999997,30.906712,30.994449999999997,31.082188,31.169925999999997,31.257664,31.345402,31.433139999999998,31.520878,31.608615999999998,31.696354,31.784091999999998,31.87183,31.959567999999997,32.047306,32.135044,32.222781999999995,32.31052,32.398258,32.485996,32.573734,32.661471999999996,32.74921,32.836948,32.924685999999994,33.012423999999996,33.100162,33.1879,33.275638,33.363376,33.451114,33.538852,33.62659,33.714327999999995,33.802065999999996,33.889804,33.977542,34.06528,34.153017999999996,34.240756,34. ...

# %% [markdown]
# ### Semi-Logarithmic Plots

# %%
df = pd.read_csv('http://www.stat.ubc.ca/~jenny/notOcto/STAT545A/examples/gapminder/data/gapminderDataFiveYear.txt', sep='\t')
df2007 = df[df.year==2007]
df1952 = df[df.year==1952]
df.head(2)

fig = {
    'data': [
        {
            'x': df2007.gdpPercap,
            'y': df2007.lifeExp,
            'text': df2007.country,
            'mode': 'markers',
            'name': '2007'},
        {
            'x': df1952.gdpPercap,
            'y': df1952.lifeExp,
            'text': "df1952.country",
            'mode': 'markers',
            'name': '1952'}
    ],
    'layout': {
        'xaxis': {'title': 'GDP per Capita', 'type': 'log'},
        'yaxis': {'title': "Life Expectancy"}
    }
}

fig = go.Figure(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1ae74272-e0b8-4a8c-b6d7-3b33b3f25a7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ae74272-e0b8-4a8c-b6d7-3b33b3f25a7e")) {                    Plotly.newPlot(                        "1ae74272-e0b8-4a8c-b6d7-3b33b3f25a7e",                        [{"mode":"markers","name":"2007","text":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo, Dem. Rep.","Congo, Rep.","Costa Rica","Cote d'Ivoire","Croatia","Cuba","Czech Republic","Denmark","Djibouti","Dominican Republic","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Ethiopia","Finland","France","Gabon","Gambia","Germany","Ghana","Greece","Guatemala","Guinea","Guinea-Bissau","Haiti","Honduras","Hong Kong, China","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kenya","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Lesotho","Liberia","Libya","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mauritius","Mexico","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Oman","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Reunion","Romania","Rwanda","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Sierra Leone","Singapore","Slovak Republic","Slovenia","Somalia","South Africa","Spain","Sri Lanka","Sudan","Swaziland","Sweden","Switzerland","Syria","Taiwan","Tanzania","Thailand","Togo","Trinidad and Tobago","Tunisia","Turkey","Uganda","United Kingdom","United States","Uruguay","Venezuela","Vietnam","West Bank and Gaza","Yemen, Rep.","Zambia","Zimbabwe"],"x":[974.5803384,5937.029526,6223.367465,4797.231267,12779.37964,34435.36744,36126.4927,29796.04834,1391.253792,33692.60508,1441.284873,3822.137084,7446.298803,12569.85177,9065.800825,10680.79282,1217.032994,430.0706916,1713.778686,2042.09524,36319.23501,706.016537,1704.063724,13171.63885,4959.114854,7006.580419,986.1478792,277.5518587,3632.557798,9645.06142,1544.750112,14619.22272,8948.102923,22833.30851,35278.41874,2082.481567,6025.374752,6873.262326,5581.180998,5728.353514,12154.08975,641.3695236,690.8055759,33207.0844,30470.0167,13206.48452,752.7497265,32170.37442,1327.60891,27538.41188,5186.050003,942.6542111,579.231743,1201.637154,3548.330846,39724.97867,18008.94444,36180.78919,2452.210407,3540.651564,11605.71449,4471.061906,40675.99635,25523.2771,28569.7197,7320.880262,31656.06806,4519.461171,1463.249282,1593.06548,23348.13973,47306.98978,10461.05868,1569.331442,414.5073415,12057.49928,1044.770126,759.3499101,12451.6558,1042.581557,1803.151496,10956.99112,11977.57496,3095.772271,9253.896111,3820.17523,823.6856205,944.0,4811.060429,1091.359778,36797.93332,25185.00911,2749.320965,619.6768924,2013.977305,49357.19017,22316.19287,2605.94758,9809.185636,4172.838464,7408.905561,3190.481016,15389.92468,20509.64777,19328.70901,7670.122558,10808.47561,863.0884639,1598.435089,21654.83194,1712.472136,9786.534714,862.5407561,47143.17964,18678.31435,25768.25759,926.1410683,9269.657808,28821.0637,3970.095407,2602.394995,4513.480643,33859.74835,37506.41907,4184.548089,28718.27684,1107.482182,7458.396327,882.9699438,18008.50924,7092.923025,8458.276384,1056.380121,33203.26128,42951.65309,10611.46299,11415.80569,2441.576404,3025.349798,2280.769906,1271.211593,469.7092981],"y":[43.828,76.423,72.301,42.731,75.32,81.235,79.829,75.635,64.062,79.441,56.728,65.554,74.852 ...

# %% [markdown]
# ### Stacked Bar Graphs

# %%
import numpy as np

N = 20
x = np.linspace(1, 10, N)
y = np.random.randn(N)+3
y2 = np.random.randn(N)+6
y3 = np.random.randn(N)+9
y4 = np.random.randn(N)+12
df = pd.DataFrame({'x': x, 'y': y, 'y2':y2, 'y3':y3, 'y4':y4})
df.head()

data = [
    go.Bar(
        x=df['x'], # assign x as the dataframe column 'x'
        y=df['y']
    ),
    go.Bar(
        x=df['x'],
        y=df['y2']
    ),
    go.Bar(
        x=df['x'],
        y=df['y3']
    ),
    go.Bar(
        x=df['x'],
        y=df['y4']
    )

]

layout = go.Layout(
    barmode='stack',
    title='Stacked Bar Graph'
)

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0d7bc873-9651-4249-94e0-7a80f2c51e71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d7bc873-9651-4249-94e0-7a80f2c51e71")) {                    Plotly.newPlot(                        "0d7bc873-9651-4249-94e0-7a80f2c51e71",                        [{"x":[1.0,1.4736842105263157,1.9473684210526314,2.4210526315789473,2.894736842105263,3.3684210526315788,3.8421052631578947,4.315789473684211,4.789473684210526,5.263157894736842,5.7368421052631575,6.2105263157894735,6.684210526315789,7.157894736842105,7.63157894736842,8.105263157894736,8.578947368421051,9.052631578947368,9.526315789473683,10.0],"y":[3.253286741194471,3.399135473402345,1.6517170540222512,4.515421013712544,3.89594629470336,2.17045616322405,3.8733083034890012,3.9945029046855822,3.2422258373515045,2.212051237316415,2.868258825537502,3.897853006054211,4.6706473724291815,4.350611454909884,1.8671176776135334,3.5608926339574722,2.1932859169698764,3.0523872029421732,1.7133124433945695,3.643052745931297],"type":"bar"},{"x":[1.0,1.4736842105263157,1.9473684210526314,2.4210526315789473,2.894736842105263,3.3684210526315788,3.8421052631578947,4.315789473684211,4.789473684210526,5.263157894736842,5.7368421052631575,6.2105263157894735,6.684210526315789,7.157894736842105,7.63157894736842,8.105263157894736,8.578947368421051,9.052631578947368,9.526315789473683,10.0],"y":[5.771354654751741,5.657385873440142,3.245926801760522,5.315511971607676,6.331861687319854,4.483591953392288,6.867623422060672,7.196863678916376,5.322031293846527,5.829503128503707,7.813900902750448,3.414078937655432,7.2692830113720985,6.681415846286558,7.128172083193992,5.716559860992702,4.8534459163188615,4.938640952759902,6.29973392518821,7.3541496053146185],"type":"bar"},{"x":[1.0,1.4736842105263157,1.9473684210526314,2.4210526315789473,2.894736842105263,3.3684210526315788,3.8421052631578947,4.315789473684211,4.789473684210526,5.263157894736842,5.7368421052631575,6.2105263157894735,6.684210526315789,7.157894736842105,7.63157894736842,8.105263157894736,8.578947368421051,9.052631578947368,9.526315789473683,10.0],"y":[8.538500034030696,7.830697231462406,8.788854555566145,7.378399818299317,7.5243145331043255,9.956664049236783,9.215526828535102,8.197315587898956,10.333940553523316,9.903376210926764,8.23428152359896,8.485829801251873,8.811578470317501,10.120442846943018,10.52980287927167,7.832065498343731,9.487761415015537,11.139296360068535,9.455364979285205,6.974290819880073],"type":"bar"},{"x":[1.0,1.4736842105263157,1.9473684210526314,2.4210526315789473,2.894736842105263,3.3684210526315788,3.8421052631578947,4.315789473684211,4.789473684210526,5.263157894736842,5.7368421052631575,6.2105263157894735,6.684210526315789,7.157894736842105,7.63157894736842,8.105263157894736,8.578947368421051,9.052631578947368,9.526315789473683,10.0],"y":[14.391264228116793,12.338549080511465,9.899298427275903,12.923563699890577,10.433330949188315,11.90400594432236,11.736860299003233,11.715841928518287,10.204948230301351,12.735063480709565,9.762034947023423,12.778401859020283,13.237714917037364,13.106936561789865,12.526911667306633,12.804044279881282,13.192496587590094,13.544908523285708,13.372821303958277,9.809970498687518],"type":"bar"}],                        {"barmode":"stack","title":{"text":"Stacked Bar Graph"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth": ...

# %% [markdown]
# ### Scatter Plots

# %%
# Attack vs. Defense of pokemon over generations, sized by HP
# source: https://www.kaggle.com/lakshyaag/data-visualization-pokemon-data

poke = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokemon.basestats.csv")

def attack_vs_def(type):
    type_data = poke[poke['Type 1'] == type]
    data = []

    for i in range(1, 7):
        gen = type_data[type_data['Generation'] == i]
        trace = go.Scatter(
            x=gen['Attack'],
            y=gen['Defense'],
            mode='markers',
            marker=dict(
                symbol='circle',
                sizemode='area',
                size=gen['HP'],
                sizeref=2. * max(gen['HP']) / (2000),
                line=dict(
                    width=2
                ),
            ),
            name='Generation {}'.format(i),
            text=type_data['Name']
        )
        data.append(trace)

    layout = go.Layout(
        showlegend=True,
        xaxis=dict(
            title="Attack"
        ),
        yaxis=dict(
            title="Defense"
        ),
        title="Attack vs. Defense of {} pokemon over generations, sized by HP".format(type)
    )

    fig = go.Figure(data=data, layout=layout)
    return fig


attack_vs_def('Electric').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="91b68b11-cecc-4eab-9151-d4fc3f7abad5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91b68b11-cecc-4eab-9151-d4fc3f7abad5")) {                    Plotly.newPlot(                        "91b68b11-cecc-4eab-9151-d4fc3f7abad5",                        [{"marker":{"line":{"width":2},"size":[35,60,25,50,40,60,65,65,90],"sizemode":"area","sizeref":0.09,"symbol":"circle"},"mode":"markers","name":"Generation 1","text":["Pikachu","Raichu","Magnemite","Magneton","Voltorb","Electrode","Electabuzz","Jolteon","Zapdos","Pichu","Mareep","Flaaffy","Ampharos","Mega Ampharos","Elekid","Raikou","Electrike","Manectric","Mega Manectric","Plusle","Minun","Shinx","Luxio","Luxray","Pachirisu","Magnezone","Electivire","Rotom","RotomHeat","RotomWash","RotomFrost","RotomFan","RotomMow","Blitzle","Zebstrika","Emolga","Tynamo","Eelektrik","Eelektross","ThundurusIncarnate Forme","ThundurusTherian Forme","Helioptile","Heliolisk","Dedenne"],"x":[55,90,35,60,30,50,83,65,90],"y":[40,55,70,95,50,70,57,60,85],"type":"scatter"},{"marker":{"line":{"width":2},"size":[20,55,70,90,90,45,90],"sizemode":"area","sizeref":0.09,"symbol":"circle"},"mode":"markers","name":"Generation 2","text":["Pikachu","Raichu","Magnemite","Magneton","Voltorb","Electrode","Electabuzz","Jolteon","Zapdos","Pichu","Mareep","Flaaffy","Ampharos","Mega Ampharos","Elekid","Raikou","Electrike","Manectric","Mega Manectric","Plusle","Minun","Shinx","Luxio","Luxray","Pachirisu","Magnezone","Electivire","Rotom","RotomHeat","RotomWash","RotomFrost","RotomFan","RotomMow","Blitzle","Zebstrika","Emolga","Tynamo","Eelektrik","Eelektross","ThundurusIncarnate Forme","ThundurusTherian Forme","Helioptile","Heliolisk","Dedenne"],"x":[40,40,55,75,95,63,85],"y":[15,40,55,85,105,37,75],"type":"scatter"},{"marker":{"line":{"width":2},"size":[40,70,70,60,60],"sizemode":"area","sizeref":0.07,"symbol":"circle"},"mode":"markers","name":"Generation 3","text":["Pikachu","Raichu","Magnemite","Magneton","Voltorb","Electrode","Electabuzz","Jolteon","Zapdos","Pichu","Mareep","Flaaffy","Ampharos","Mega Ampharos","Elekid","Raikou","Electrike","Manectric","Mega Manectric","Plusle","Minun","Shinx","Luxio","Luxray","Pachirisu","Magnezone","Electivire","Rotom","RotomHeat","RotomWash","RotomFrost","RotomFan","RotomMow","Blitzle","Zebstrika","Emolga","Tynamo","Eelektrik","Eelektross","ThundurusIncarnate Forme","ThundurusTherian Forme","Helioptile","Heliolisk","Dedenne"],"x":[45,75,75,50,40],"y":[40,60,80,40,50],"type":"scatter"},{"marker":{"line":{"width":2},"size":[45,60,80,60,70,75,50,50,50,50,50,50],"sizemode":"area","sizeref":0.08,"symbol":"circle"},"mode":"markers","name":"Generation 4","text":["Pikachu","Raichu","Magnemite","Magneton","Voltorb","Electrode","Electabuzz","Jolteon","Zapdos","Pichu","Mareep","Flaaffy","Ampharos","Mega Ampharos","Elekid","Raikou","Electrike","Manectric","Mega Manectric","Plusle","Minun","Shinx","Luxio","Luxray","Pachirisu","Magnezone","Electivire","Rotom","RotomHeat","RotomWash","RotomFrost","RotomFan","RotomMow","Blitzle","Zebstrika","Emolga","Tynamo","Eelektrik","Eelektross","ThundurusIncarnate Forme","ThundurusTherian Forme","Helioptile","Heliolisk","Dedenne"],"x":[65,85,120,45,70,123,50,65,65,65,65,65],"y":[34,49,79,70,115,67,77,107,107,107,107,107],"type":"scatter"},{"marker":{"line":{"width":2},"size":[45,75,55,35,65,85,79,79],"sizemode":"area","sizeref":0.085,"symbol":"circle"},"mode":"markers","name":"Generation 5","text":["Pikachu","Raichu","Magnemite","Magneton","Voltorb","Electrode","Electabuzz","Jolteon","Zapdos","Pichu","Mareep","Flaaffy","Ampharos","Mega Ampharos","Elekid","Raikou","Electrike","Manectric","Mega Manectric","Plusle","Minun","Shinx","Luxio","Luxray","Pachirisu", ...

# %% [markdown]
# ### Line Charts

# %%
# Visualizing the trend of stats by type and generation.
# source: https://www.kaggle.com/lakshyaag/data-visualization-pokemon-data

poke = pd.read_csv("https://raw.githubusercontent.com/iamamangosteen/pythonforbusiness/master/pokemon.basestats.csv")

def stats_by(classifier):
    data = []
    stats_names = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
    stats = poke.groupby(classifier)[stats_names].mean().reset_index()
    for stat in stats_names:
        stat_line = go.Scatter(
            x=stats[classifier],
            y=stats[stat],
            name=stat,
            line=dict(
                width=3,
            ),
        )

        data.append(stat_line)

    layout = go.Layout(
        title='Trend of stats by {}'.format(classifier),
        xaxis=dict(title=classifier),
        yaxis=dict(title='Values')
    )

    trend = go.Figure(data=data, layout=layout)
    trend.show()


stats_by('Generation')
stats_by('Type 1')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ec2d32c9-5a32-4c08-bb9c-1a14a07931b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec2d32c9-5a32-4c08-bb9c-1a14a07931b8")) {                    Plotly.newPlot(                        "ec2d32c9-5a32-4c08-bb9c-1a14a07931b8",                        [{"line":{"width":3},"name":"HP","x":[1,2,3,4,5,6],"y":[65.81927710843374,71.20754716981132,66.54375,73.08264462809917,71.78787878787878,68.26829268292683],"type":"scatter"},{"line":{"width":3},"name":"Attack","x":[1,2,3,4,5,6],"y":[76.63855421686748,72.02830188679245,81.625,82.86776859504133,82.06666666666666,75.8048780487805],"type":"scatter"},{"line":{"width":3},"name":"Defense","x":[1,2,3,4,5,6],"y":[70.86144578313252,73.38679245283019,74.1,78.13223140495867,72.32727272727273,76.6829268292683],"type":"scatter"},{"line":{"width":3},"name":"Sp. Atk","x":[1,2,3,4,5,6],"y":[71.81927710843374,65.94339622641509,75.80625,76.40495867768595,71.98787878787878,74.29268292682927],"type":"scatter"},{"line":{"width":3},"name":"Sp. Def","x":[1,2,3,4,5,6],"y":[69.09036144578313,73.90566037735849,71.225,77.1900826446281,68.73939393939393,74.89024390243902],"type":"scatter"},{"line":{"width":3},"name":"Speed","x":[1,2,3,4,5,6],"y":[72.58433734939759,61.81132075471698,66.925,71.33884297520662,68.07878787878788,66.4390243902439],"type":"scatter"}],                        {"title":{"text":"Trend of stats by Generation"},"xaxis":{"title":{"text":"Generation"}},"yaxis":{"title":{"text":"Values"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02d8a97e-9ffd-4407-bdd1-62081aa2c8ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02d8a97e-9ffd-4407-bdd1-62081aa2c8ae")) {                    Plotly.newPlot(                        "02d8a97e-9ffd-4407-bdd1-62081aa2c8ae",                        [{"line":{"width":3},"name":"HP","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"y":[56.88405797101449,66.80645161290323,83.3125,59.79545454545455,74.11764705882354,69.85185185185185,69.90384615384616,70.75,64.4375,67.27142857142857,73.78125,72.0,77.27551020408163,67.25,70.63157894736842,65.36363636363636,65.22222222222223,72.0625],"type":"scatter"},{"line":{"width":3},"name":"Attack","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"y":[70.97101449275362,88.38709677419355,112.125,69.0909090909091,61.529411764705884,96.77777777777777,84.76923076923077,78.75,73.78125,73.21428571428571,95.75,72.75,73.46938775510205,74.67857142857143,71.45614035087719,92.86363636363636,92.70370370370371,74.15178571428571],"type":"scatter"},{"line":{"width":3},"name":"Defense","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"y":[70.72463768115942,70.2258064516129,86.375,66.29545454545455,65.70588235294117,65.92592592592592,67.76923076923077,66.25,81.1875,70.8,84.84375,71.41666666666667,59.8469387755102,68.82142857142857,67.6842105263158,100.79545454545455,126.37037037037037,72.94642857142857],"type":"scatter"},{"line":{"width":3},"name":"Sp. Atk","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"y":[53.869565217391305,74.64516129032258,96.84375,90.02272727272727,78.52941176470588,53.111111111111114,88.98076923076923,94.25,79.34375,77.5,56.46875,77.54166666666667,55.816326530612244,60.42857142857143,98.40350877192982,63.34090909090909,67.51851851851852,74.8125],"type":"scatter"},{"line":{"width":3},"name":"Sp. Def","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"y":[64.79710144927536,69.51612903225806,88.84375,73.70454545454545,84.70588235294117,64.70370370370371,72.21153846153847,72.5,76.46875,70.42857142857143,62.75,76.29166666666667,63.724489795918366,64.39285714285714,86.28070175438596,75.47727272727273,80.62962962962963,70.51785714285714],"type":"scatter"},{"line":{"width":3},"name":"Speed","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"y":[61.68115942028985,76.16129032258064,83.03125,84.5,48.588235294117645,66.07407407407408,74.4423076923077,102.5,64.34375,61.92857142857143,63.90625,63.458333333333336,71.55102040816327,63.57142857142857,81.49122807017544,55.90909090909091,55.25925925925926,65.96428571428571],"type":"scatter"}],                        {"title":{"text":"Trend of stats by Type 1"},"xaxis":{"title":{"text":"Type 1"}},"yaxis":{"title":{"text":"Values"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %% [markdown]
# ### We'll stop introducing Plot.ly here
# - there's still plenty more that can be done with plot.ly, but this should serve as a good introduction to create basic plots.
# - for additional resources, please do check out the [plotly documentation](https://plotly.com/python/)!
